# %% [markdown]
# ## Stock prices - Scraping
#
# Done by Wieland Vandebotermet

# %% [markdown]
# First We Have 3 models: an Individual model, An timeseries Pycaret Model and a AWS DeepAR Model.
#
# Please not the AWS model training part does not work here locally.

# %% [markdown]
# ## The Required Imports & Venv

# %% [markdown]
# python3.10 -m venv StockPrediction

# %%
# %pip install pandas numpy scikit-learn tensorflow pycaret matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from io import StringIO
import re

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

from pycaret.time_series import *
from pycaret.utils.time_series import clean_time_index

# %%
#import sagemaker
#from sagemaker.estimator import Estimator
#from sagemaker.transformer import Transformer
#from sagemaker.inputs import TrainingInput
#from sagemaker import get_execution_role

#import boto3

# %% [markdown]
# # 1. The Individual Model

# %% [markdown]
# ## Choosing the model

# %% [markdown]
# When searching for a model suited for this task the only recommendend model type i could find was LSTM. When searching for a few others i couln't really find much else suited for the task. With nothing better suited To the Task.

# %% [markdown]
# 1. Long Short-Term Memory (LSTM) Neural Networks:
#
#     * Why LSTM?
#         * LSTMs are specifically designed to handle sequential data like stock prices, where the order of data points matters.
#         * They are capable of learning patterns over time and can manage dependencies from the past.
#         * Stock prices often involve trends and seasonality, which LSTMs can capture effectively.
#     * How does it do this:
#         * Uses input gates, forget gates, and output gates to decide which information to keep or discard.
#         Wich allow it to dynamically adapt to varying time dependencies in the data.

# %% [markdown]
# 2. Linear Regression with Feature Engineering:
#
#     * Why Linear Regression?
#         * A simpler, interpretable approach that works well for basic predictions if the dataset isn’t highly complex.
#         * You can create features like daily price changes, moving averages, or relative price differences between the two companies to predict the price movement of one based on the other.
#     * How does it do this:
#         * Linear regression assumes a linear relationship between the target variable and the predictor variables​. The model estimates the coefficients.
#         * Feature engineering involves creating new input features or transforming existing ones to better capture patterns and relationships in the data.

# %% [markdown]
# 3. ARIMA (AutoRegressive Integrated Moving Average):
#
#     * Why ARIMA?
#         * Ideal for univariate time-series forecasting when the focus is on one company’s historical stock data.
#         * Can help you project near-term prices for one company, which can then inform predictions about the other company.
#     * How does it do this:
#         * AutoRegression (AR) captures the relationship between the current value and a series of past values (lags) and uses the lagged version of the target variable as input predictors.
#         * Integration (I) makes the data stationary by differencing it (subtracting past values).
#         * Moving Average (MA) models the relationship between the current value and past forecast errors (residuals).

# %% [markdown]
# ## Building The Model

# %%
AMD = pd.read_csv('./Data/AMD_CleanedDaily.csv', parse_dates=['datetime'], index_col='datetime')
Intel = pd.read_csv('./Data/Intel_CleanedDaily.csv', parse_dates=['datetime'], index_col='datetime')

# Merge datasets on datetime
data = pd.merge(AMD, Intel, left_index=True, right_index=True, suffixes=('_amd', '_intel'))

# Define target and features
target = 'adj_close_amd'  # Predict chosen companies's adj_close

features = data.columns.drop(target)  # Use all other columns as features

# %%
# Normalize the features and target
scalers = {}
scaled_data = pd.DataFrame(index=data.index)

# Normalize each column
for col in data.columns:
    scalers[col] = MinMaxScaler(feature_range=(0, 1))
    scaled_data[col] = scalers[col].fit_transform(data[col].values.reshape(-1, 1))

# Prepare sequences with AMD and Intel features
def create_sequences(data, target_col, sequence_length):
    x, y = [], []
    for i in range(sequence_length, len(data)):
        x.append(data.iloc[i-sequence_length:i].values)  # All features
        y.append(data.iloc[i][target_col])  # Target column
    return np.array(x), np.array(y)

sequence_length = 60

# Split the data into training and testing sets
# Reserve the last month as the test set
last_month_index = -30  # Assuming daily data; adjust for your frequency
train_data = scaled_data.iloc[:last_month_index]
test_data = scaled_data.iloc[last_month_index - sequence_length:]  # Include sequence length for context

x_train, y_train = create_sequences(train_data, target, sequence_length)
x_test, y_test = create_sequences(test_data, target, sequence_length)

# Reshape for LSTM (samples, time steps, features)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2]))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], x_test.shape[2]))

# %%
# Define the LSTM model with Input
model = Sequential([
    Input(shape=(x_train.shape[1], x_train.shape[2])),  # Explicitly define the input shape
    LSTM(units=100, return_sequences=True, kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    LSTM(units=100, return_sequences=False),
    Dropout(0.2),
    Dense(units=50),
    Dense(units=1)  # Single output for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Train the model

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, batch_size=32, epochs=25, validation_data=(x_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/25
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 16s 43ms/step - loss: 0.0817 - val_loss: 0.0014
# Epoch 2/25
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - loss: 0.0010 - val_loss: 8.1745e-04
# Epoch 3/25
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - loss: 7.4807e-04 - val_loss: 9.5753e-04
# Epoch 4/25
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - loss: 9.4673e-04 - val_loss: 0.0017
# Epoch 5/25
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - loss: 7.9133e-04 - val_loss: 0.0027

# %% [markdown]
# ## Evaluating the model

# %%
# Evaluate the model
train_loss = model.evaluate(x_train, y_train)
test_loss = model.evaluate(x_test, y_test)
print(f"Train Loss: {train_loss}, Test Loss: {test_loss}")

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'MAE: {mae}, RMSE: {rmse}')
# Out:
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 2.9407e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 8.1745e-04
# Train Loss: 0.00046387340989895165, Test Loss: 0.0008174482500180602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# MAE: 0.020974864851322893, RMSE: 0.0241117168428493

# %% [markdown]
# ## Predicting Stock Prices

# %%
# Predict for the last month
predictions = model.predict(x_test)
predictions_LSTM = scalers[target].inverse_transform(predictions)
y_test_actual = scalers[target].inverse_transform(y_test.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Prices (Last Month)')
plt.plot(predictions_LSTM, color='red', label='Predicted Prices (Last Month)')
plt.title('Stock Price Prediction (Last Month)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %% [markdown]
# ## Saving the model

# %%
# model.save('./Models/STLMPredictAMDStockPrice.keras')

# %% [markdown]
# # 2 Pycaret Model

# %% [markdown]
# ## Setting up the data

# %% [markdown]
# We have to limit the amount of rows due to ram limitations, and as such we wil remove all data from before 2010.

# %%
# Load the datasets
AMD = pd.read_csv('./Data/AMD_CleanedDaily.csv', parse_dates=['datetime'])
AMD = AMD[['datetime', 'adj_close']]

Intel = pd.read_csv('./Data/Intel_CleanedDaily.csv', parse_dates=['datetime'])

# Set datetime as the index
AMD.set_index('datetime', inplace=True)
Intel.set_index('datetime', inplace=True)

# Merge datasets on datetime index
data = pd.merge(AMD, Intel, left_index=True, right_index=True, suffixes=('_amd', '_intel'))
data = data[data.index.year >= 2010]

# Train-test split: reserve the last month for testing
train_data = data.iloc[:-30]  # Training data (all but the last 30 rows)
test_data = data.iloc[-30:]   # Testing data (the last 30 rows)

# Convert indices to datetime and set frequency explicitly
train_data.index = pd.to_datetime(train_data.index)
test_data.index = pd.to_datetime(test_data.index)

# Ensure the datetime index has a consistent frequency (e.g., daily)
train_data.index = train_data.index.to_period('D')
test_data.index = test_data.index.to_period('D')

train_data = clean_time_index(data=train_data, freq='D')
test_data = clean_time_index(data=test_data, freq='D')

train_data = train_data.fillna(train_data.mean())
test_data = test_data.fillna(test_data.mean())

# %% [markdown]
# ## The Model Building and Training

# %%
# PyCaret setup
exp = setup(
    data=train_data[-1000:],
    target='adj_close_amd',  # The target variable for forecasting
    fh=30,  # Forecast horizon of 30 days
    session_id=369,
    seasonal_period=7,
    numeric_imputation_target='mean',
    numeric_imputation_exogenous='mean',
)

# Compare models and choose the best one
best_model = exp.compare_models(errors="ignore", fold=3)
# Out:
# <style type="text/css">
# #T_f006e_row25_col1, #T_f006e_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f006e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f006e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f006e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f006e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f006e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f006e_row0_col1" class="data row0 col1" >369</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f006e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f006e_row1_col1" class="data row1 col1" >adj_close_amd</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f006e_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_f006e_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f006e_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_f006e_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f006e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_f006e_row4_col1" class="data row4 col1" >(1000, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f006e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_f006e_row5_col1" class="data row5 col1" >(1000, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f006e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_f006e_row6_col1" class="data row6 col1" >(970, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f006e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_f006e_row7_col1" class="data row7 col1" >(30, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f006e_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_f006e_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f006e_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_f006e_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f006e_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_f006e_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f006e_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_f006e_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f006e_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_f006e_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f006e_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_f006e_row13_col1" class="data row13 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f006e_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_f006e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f006e_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_f006e_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f006e_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_f006e_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f006e_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_f006e_row17_col1" class="data row17 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f006e_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_f006e_row18_col1" class="data row18 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f006e_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_f006e_row19_col1" class="data row19 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f006e_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_f006e_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f006e_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_f006e_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f006e_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_f006e_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f006e_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_f006e_row23_col1" class="data row23 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f006e_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_f006e_row24_col1" class="data row24 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f006e_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_f006e_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f006e_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_f006e_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f006e_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_f006e_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f006e_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_f006e_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f006e_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_f006e_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f006e_level0_row30" class="row_head
# <style type="text/css">
# #T_a0856 th {
#   text-align: left;
# }
# #T_a0856_row0_col0, #T_a0856_row0_col2, #T_a0856_row0_col4, #T_a0856_row1_col0, #T_a0856_row1_col1, #T_a0856_row1_col3, #T_a0856_row1_col5, #T_a0856_row1_col6, #T_a0856_row1_col7, #T_a0856_row2_col0, #T_a0856_row2_col1, #T_a0856_row2_col2, #T_a0856_row2_col3, #T_a0856_row2_col4, #T_a0856_row2_col5, #T_a0856_row2_col6, #T_a0856_row2_col7, #T_a0856_row3_col0, #T_a0856_row3_col1, #T_a0856_row3_col2, #T_a0856_row3_col3, #T_a0856_row3_col4, #T_a0856_row3_col5, #T_a0856_row3_col6, #T_a0856_row3_col7, #T_a0856_row4_col0, #T_a0856_row4_col1, #T_a0856_row4_col2, #T_a0856_row4_col3, #T_a0856_row4_col4, #T_a0856_row4_col5, #T_a0856_row4_col6, #T_a0856_row4_col7, #T_a0856_row5_col0, #T_a0856_row5_col1, #T_a0856_row5_col2, #T_a0856_row5_col3, #T_a0856_row5_col4, #T_a0856_row5_col5, #T_a0856_row5_col6, #T_a0856_row5_col7, #T_a0856_row6_col0, #T_a0856_row6_col1, #T_a0856_row6_col2, #T_a0856_row6_col3, #T_a0856_row6_col4, #T_a0856_row6_col5, #T_a0856_row6_col6, #T_a0856_row6_col7, #T_a0856_row7_col0, #T_a0856_row7_col1, #T_a0856_row7_col2, #T_a0856_row7_col3, #T_a0856_row7_col4, #T_a0856_row7_col5, #T_a0856_row7_col6, #T_a0856_row7_col7, #T_a0856_row8_col0, #T_a0856_row8_col1, #T_a0856_row8_col2, #T_a0856_row8_col3, #T_a0856_row8_col4, #T_a0856_row8_col5, #T_a0856_row8_col6, #T_a0856_row8_col7, #T_a0856_row9_col0, #T_a0856_row9_col1, #T_a0856_row9_col2, #T_a0856_row9_col3, #T_a0856_row9_col4, #T_a0856_row9_col5, #T_a0856_row9_col6, #T_a0856_row9_col7, #T_a0856_row10_col0, #T_a0856_row10_col1, #T_a0856_row10_col2, #T_a0856_row10_col3, #T_a0856_row10_col4, #T_a0856_row10_col5, #T_a0856_row10_col6, #T_a0856_row10_col7, #T_a0856_row11_col0, #T_a0856_row11_col1, #T_a0856_row11_col2, #T_a0856_row11_col3, #T_a0856_row11_col4, #T_a0856_row11_col5, #T_a0856_row11_col6, #T_a0856_row11_col7, #T_a0856_row12_col0, #T_a0856_row12_col1, #T_a0856_row12_col2, #T_a0856_row12_col3, #T_a0856_row12_col4, #T_a0856_row12_col5, #T_a0856_row12_col6, #T_a0856_row12_col7, #T_a0856_row13_col0, #T_a0856_row13_col1, #T_a0856_row13_col2, #T_a0856_row13_col3, #T_a0856_row13_col4, #T_a0856_row13_col5, #T_a0856_row13_col6, #T_a0856_row13_col7, #T_a0856_row14_col0, #T_a0856_row14_col1, #T_a0856_row14_col2, #T_a0856_row14_col3, #T_a0856_row14_col4, #T_a0856_row14_col5, #T_a0856_row14_col6, #T_a0856_row14_col7, #T_a0856_row15_col0, #T_a0856_row15_col1, #T_a0856_row15_col2, #T_a0856_row15_col3, #T_a0856_row15_col4, #T_a0856_row15_col5, #T_a0856_row15_col6, #T_a0856_row15_col7, #T_a0856_row16_col0, #T_a0856_row16_col1, #T_a0856_row16_col2, #T_a0856_row16_col3, #T_a0856_row16_col4, #T_a0856_row16_col5, #T_a0856_row16_col6, #T_a0856_row16_col7, #T_a0856_row17_col0, #T_a0856_row17_col1, #T_a0856_row17_col2, #T_a0856_row17_col3, #T_a0856_row17_col4, #T_a0856_row17_col5, #T_a0856_row17_col6, #T_a0856_row17_col7 {
#   text-align: left;
# }
# #T_a0856_row0_col1, #T_a0856_row0_col3, #T_a0856_row0_col5, #T_a0856_row0_col6, #T_a0856_row0_col7, #T_a0856_row1_col2, #T_a0856_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a0856_row0_col8, #T_a0856_row1_col8, #T_a0856_row2_col8, #T_a0856_row3_col8, #T_a0856_row4_col8, #T_a0856_row5_col8, #T_a0856_row6_col8, #T_a0856_row7_col8, #T_a0856_row8_col8, #T_a0856_row9_col8, #T_a0856_row10_col8, #T_a0856_row11_col8, #T_a0856_row13_col8, #T_a0856_row14_col8, #T_a0856_row15_col8, #T_a0856_row16_col8, #T_a0856_row17_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a0856_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a0856">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0856_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a0856_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_a0856_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_a0856_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_a0856_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_a0856_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_a0856_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_a0856_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_a0856_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0856_level0_row0" class="row_heading level0 row0" >arima</th>
#       <td id="T_a0856_row0_col0" class="data row0 col0" >ARIMA</td>
#       <td id="T_a0856_row0_col1" class="data row0 col1" >1.0249</td>
#       <td id="T_a0856_row0_col2" class="data row0 col2" >0.5883</td>
#       <td id="T_a0856_row0_col3" class="data row0 col3" >6.8402</td>
#       <td id="T_a0856_row0_col4" class="data row0 col4" >9.5349</td>
#       <td id="T_a0856_row0_col5" class="data row0 col5" >0.0809</td>
#       <td id="T_a0856_row0_col6" class="data row0 col6" >0.0776</td>
#       <td id="T_a0856_row0_col7" class="data row0 col7" >0.9327</td>
#       <td id="T_a0856_row0_col8" class="data row0 col8" >1.4167</td>
#     </tr>
#     <tr>
#       <th id="T_a0856_level0_row1" class="row_heading level0 row1" >auto_arima</th>
#       <td id="T_a0856_row1_col0" class="data row1 col0" >Auto ARIMA</td>
#       <td id="T_a0856_row1_col1" class="data row1 col1" >1.0874</td>
#       <td id="T_a0856_row1_col2" class="data row1 col2" >0.5655</td>
#       <td id="T_a0856_row1_col3" class="data row1 col3" >7.2521</td>
#       <td id="T_a0856_row1_col4" class="data row1 col4" >9.1595</td>
#       <td id="T_a0856_row1_col5" class="data row1 col5" >0.1254</td>
#       <td id="T_a0856_row1_col6" class="data row1 col6" >0.1150</td>
#       <td id="T_a0856_row1_col7" class="data row1 col7" >0.9307</td>
#       <td id="T_a0856_row1_col8" class="data row1 col8" >41.9133</td>
#     </tr>
#     <tr>
#       <th id="T_a0856_level0_row2" class="row_heading level0 row2" >ridge_cds_dt</th>
#       <td id="T_a0856_row2_col0" class="data row2 col0" >Ridge w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_a0856_row2_col1" class="data row2 col1" >1.9108</td>
#       <td id="T_a0856_row2_col2" class="data row2 col2" >1.0973</td>
#       <td id="T_a0856_row2_col3" class="data row2 col3" >12.7366</td>
#       <td id="T_a0856_row2_col4" class="data row2 col4" >17.7769</td>
#       <td id="T_a0856_row2_col5" class="data row2 col5" >0.2184</td>
#       <td id="T_a0856_row2_col6" class="data row2 col6" >0.2017</td>
#       <td id="T_a0856_row2_col7" class="data row2 col7" >0.7757</td>
#       <td id="T_a0856_row2_col8" class="data row2 col8" >1.3033</td>
#     </tr>
#     <tr>
#       <th id="T_a0856_level0_row3" class="row_heading level0 row3" >lr_cds_dt</th>
#       <td id="T_a0856_row3_col0" class="data row3 col0" >Linear w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_a0856_row3_col1" class="data row3 col1" >1.9113</td>
#       <td id="T_a0856_row3_col2" class="data row3 col2" >1.0974</td>
#       <td id="T_a0856_row3_col3" class="data row3 col3" >12.7398</td>
#       <td id="T_a0856_row3_col4" class="data row3 col4" >17.7799</td>
#       <td id="T_a0856_row3_col5" class="data row3 col5" >0.2185</td>
#       <td id="T_a0856_row3_col6" class="data row3 col6" >0.2018</td>
#       <td id="T_a0856_row3_col7" class="data row3 col7" >0.7756</td>
#       <td id="T_a0856_row3_col8" class="data row3 col8" >1.5267</td>
#     </tr>
#     <tr>
#       <th id="T_a0856_level0_row4" class="row_heading level0 row4" >br_cds_dt</th>
#       <td id="T_a0856_row4_col0" class="data row4 col0" >Bayesian Ridge w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_a0856_row4_col1" class="data row4 col1" >1.9616</td>
#       <td id="T_a0856_row4_col2" class="data row4 col2" >1.1310</td>
#       <td id="T_a0856_row4_col3" class="data row4 col3" >13.0723</td>
#       <td id="T_a0856_row4_col4" class="data row4 col4" >18.3213</td>
#       <td id="T_a0856_row4_col5" class="data row4 col5" >0.2160</td>
#       <td id="T_a0856_row4_col6" class="data row4 col6" >0.1960</

# %%
# PyCaret setup
exp = setup(
    data=train_data,
    target='adj_close_amd',  # The target variable for forecasting
    fh=30,  # Forecast horizon of 30 days
    session_id=369,
    seasonal_period=7,
    numeric_imputation_target='mean',
    numeric_imputation_exogenous='mean',
)

# Finalize the model
final_model = exp.finalize_model(best_model)
# Out:
# <style type="text/css">
# #T_3dbb6_row25_col1, #T_3dbb6_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3dbb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dbb6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3dbb6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dbb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dbb6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3dbb6_row0_col1" class="data row0 col1" >369</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3dbb6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3dbb6_row1_col1" class="data row1 col1" >adj_close_amd</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3dbb6_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_3dbb6_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3dbb6_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_3dbb6_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3dbb6_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3dbb6_row4_col1" class="data row4 col1" >(4974, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3dbb6_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3dbb6_row5_col1" class="data row5 col1" >(4974, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3dbb6_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3dbb6_row6_col1" class="data row6 col1" >(4944, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3dbb6_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3dbb6_row7_col1" class="data row7 col1" >(30, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3dbb6_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_3dbb6_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3dbb6_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_3dbb6_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3dbb6_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_3dbb6_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3dbb6_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_3dbb6_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3dbb6_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_3dbb6_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3dbb6_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_3dbb6_row13_col1" class="data row13 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3dbb6_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_3dbb6_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3dbb6_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_3dbb6_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3dbb6_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_3dbb6_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3dbb6_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_3dbb6_row17_col1" class="data row17 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3dbb6_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_3dbb6_row18_col1" class="data row18 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3dbb6_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_3dbb6_row19_col1" class="data row19 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3dbb6_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_3dbb6_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3dbb6_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_3dbb6_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3dbb6_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_3dbb6_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3dbb6_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_3dbb6_row23_col1" class="data row23 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3dbb6_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_3dbb6_row24_col1" class="data row24 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3dbb6_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_3dbb6_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3dbb6_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_3dbb6_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3dbb6_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_3dbb6_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3dbb6_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_3dbb6_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3dbb6_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_3dbb6_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3dbb6_level0_row30" class="row_hea

# %% [markdown]
# ## Predicting the last month

# %%
data.head()
# Out:
#                            adj_close_amd  adj_close_intel      close  \
# datetime
# 2010-01-04 00:00:00+00:00           9.70        13.519428  20.879999
# 2010-01-05 00:00:00+00:00           9.71        13.512947  20.870001
# 2010-01-06 00:00:00+00:00           9.57        13.467630  20.799999
# 2010-01-07 00:00:00+00:00           9.47        13.338131  20.600000
# 2010-01-08 00:00:00+00:00           9.43        13.487055  20.830000
#
#                                 high    low       open    volume
# datetime
# 2010-01-04 00:00:00+00:00  21.030001  20.73  20.790001  47800900
# 2010-01-05 00:00:00+00:00  20.990000  20.60  20.940001  52357700
# 2010-01-06 00:00:00+00:00  20.930000  20.67  20.809999  40037400
# 2010-01-07 00:00:00+00:00  20.760000  20.34  20.730000  54041500
# 2010-01-08 00:00:00+00:00  20.889999  20.40  20.540001  48234700

# %%
exogenous_features = [
    'adj_close_intel',
    'close', 'high', 'low', 'open', 'volume'
]
# Exogenous variables for prediction (using both AMD and Intel for forecasting)
exog_test = test_data[exogenous_features].tail(30)
exog_test = exog_test.fillna(exog_test.mean())

# Make predictions
forecast = predict_model(final_model, fh=30, X=exog_test)

# Transform the values for plotting
actual_values = test_data['adj_close_amd'][-30:].values.flatten()
actual_values_series = pd.Series(actual_values)
actual_values = actual_values_series.fillna(actual_values_series.mean())
Pycaret_Predictions = forecast['y_pred'].values.flatten()

# Convert the Period index to DatetimeIndex for plotting
dates = test_data.index[-30:].to_timestamp()  # Convert Period to DatetimeIndex

# Plotting the actual vs forecasted values
plt.figure(figsize=(10, 6))
plt.plot(dates, actual_values, label='Actual', color='blue', marker='o')  # Actual values in blue
plt.plot(dates, Pycaret_Predictions, label='Forecast', color='red', linestyle='--', marker='x')  # Forecast values in red

# Adding labels and title
plt.title('Actual vs Forecasted Stock Prices')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()

# Display the plot
plt.xticks(rotation=45)  # Rotate date labels for better visibility
plt.tight_layout()
plt.show()

# %%
#save_model(final_model, './Models/PycaretAMD_Adj_Close')

# %% [markdown]
# # 3 AWS DeepAR Model

# %% [markdown]
# ## Setting up the buckets

# %% [raw]
# role = get_execution_role()
# region = boto3.Session().region_name
#
# # S3 bucket for saving code and model artifacts.
# bucket = sagemaker.Session().default_bucket()
# prefix = "sagemaker/StockPrices"
# bucket_path = "https://s3-{}.amazonaws.com/{}".format(region, bucket)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Setting up the data

# %% [raw]
# # Load the stock data
# AMD = pd.read_csv('./AMD_CleanedDaily.csv', parse_dates=['datetime'], index_col='datetime')
# Intel = pd.read_csv('./Intel_CleanedDaily.csv', parse_dates=['datetime'], index_col='datetime')
#
# # Merge datasets on datetime (for multi-stock prediction)
# data = pd.merge(AMD, Intel, left_index=True, right_index=True, suffixes=('_amd', '_intel'))
#
# sequence_length = 60
# last_month_index = -30
#
# # Split the data for training, validation, and testing
# split_data = data.iloc[:last_month_index]
# split_index = int(len(split_data) * 0.9)
#
# train_data= split_data.iloc[:split_index]
# validation_data = split_data.iloc[split_index:]
#
# test_data = data.iloc[last_month_index - sequence_length:]  # Include sequence length for context
#
#
# def create_json_format(data_split):
#     # Ensure the 'start' field is formatted correctly as ISO 8601 string
#     start_time = data_split.index[0].strftime('%Y-%m-%dT%H:%M:%S')
#     # Ensure the target field is 1D by selecting the 'adj_close_amd' column directly and flattening it
#     target_values = data_split['adj_close_amd'].values.reshape(-1).tolist()  # Flatten to 1D list
#     # Return the formatted JSON structure
#     return {
#         "start": start_time,   # Timestamp in ISO 8601 format
#         "target": target_values  # 1D list of target values
#     }
#
# # Convert train, validation, and test sets into the required format
# train_data_json = create_json_format(train_data)
# val_data_json = create_json_format(validation_data)
# test_data_json = create_json_format(test_data)
#
# with open('train_data.json', 'w') as f:
#     json.dump(train_data_json, f)
#
# with open('val_data.json', 'w') as f:
#     json.dump(val_data_json, f)
#
# with open('test_data.json', 'w') as f:
#     json.dump(test_data_json, f)
#
# # Upload the Parquet files to S3 for SageMaker
# sagemaker.Session().upload_data(
#     "train_data.json", bucket=bucket, key_prefix=prefix + "/" + "training"
# )
#
# sagemaker.Session().upload_data(
#     "val_data.json", bucket=bucket, key_prefix=prefix + "/" + "validation"
# )
#
# sagemaker.Session().upload_data(
#     "test_data.json", bucket=bucket, key_prefix=prefix + "/" + "test"
# )

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Building the model and training it

# %% [raw]
# output_path = f"s3://{bucket}/{prefix}/output/"
#
# # Set up SageMaker DeepAR estimator
# deepar_estimator = Estimator(
#     image_uri=sagemaker.image_uris.retrieve(
#         framework='forecasting-deepar',
#         region=sagemaker.Session().boto_region_name  # Automatically detects your region
#     ),
#     role=get_execution_role(),
#     instance_count=1,
#     instance_type='ml.m4.xlarge',
#     base_job_name='deepar-stock-prediction',
#     output_path=output_path  # S3 output location for model artifacts
# )
#
# deepar_estimator.set_hyperparameters(
#     time_freq='D', # daily series
#     context_length= 30,
#     prediction_length= 30, # number of data points to predict
#     num_cells=40,
#     num_layers=2,
#     epochs=100,
#     mini_batch_size=32,
#     learning_rate=0.00001,
#     dropout_rate=0.05,
#     early_stopping_patience=10,
# )
#
# # Prepare S3 URIs for training and validation data
# train_data_s3_uri = f"s3://{bucket}/{prefix}/training/train_data.json"
# validation_data_s3_uri = f"s3://{bucket}/{prefix}/validation/val_data.json"
#
# # Create TrainingInput objects
# train_input = TrainingInput(train_data_s3_uri, content_type="json")
# validation_input = TrainingInput(validation_data_s3_uri, content_type="json")
#
# # Launch training job
# deepar_estimator.fit({'train': train_input, 'test': validation_input})

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Deploying the model and predicting

# %% [raw]
# # Deploy the model as an endpoint
# predictor = deepar_estimator.deploy(
#     initial_instance_count=1,
#     instance_type='ml.m4.xlarge'
# )

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# input_data = {
#     "instances": [
#         {
#             "start": test_data_json["start"],  # Use the 'start' from the test_data_json
#             "target": test_data_json["target"]  # Use the 'target' from the test_data_json
#         }
#     ]
# }
#
# # Convert to JSON string
# input_data_json_str = json.dumps(input_data)
#
# # Create a SageMaker runtime client
# sagemaker_runtime = boto3.client('sagemaker-runtime')
#
# # Endpoint name
# endpoint_name = "deepar-stock-prediction-2024-11-28-09-28-33-283"  # Replace with your actual endpoint name
#
# # Invoke the endpoint with the correct content type
# response = sagemaker_runtime.invoke_endpoint(
#     EndpointName=endpoint_name,
#     ContentType='application/json',  # Ensure the content type is set to JSON
#     Body=input_data_json_str
# )
#
# # Process the response
# predictions = json.loads(response['Body'].read().decode('utf-8'))
#
# # Extract predicted values
# DeepAR_prediction = predictions['predictions'][0]['mean']

# %% [raw]
# actual = data["adj_close_amd"].iloc[-30:].values  # Last 30 days of actual data
#
# # Plotting the actual and predicted prices
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(10, 6))
# plt.plot(actual, label='Actual Prices', color='blue', marker='o')
# plt.plot(DeepAR_prediction, label='Predicted Prices', color='red', linestyle='--', marker='x')
#
# plt.title('Stock Price Prediction (DeepAR)', fontsize=16)
# plt.xlabel('Time', fontsize=14)
# plt.ylabel('Stock Price', fontsize=14)
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4 Comparing the models

# %%
# Read the preditions previosly saved fromt the DeepAR model.
DeepAR_prediction = pd.read_csv('./Data/DeepAR_prediction_values.csv')

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(Pycaret_Predictions, label='Predicted Prices Pycaret', color='purple')
plt.plot(DeepAR_prediction, label='Predicted Prices DeepAR', color='orange')
plt.plot(predictions_LSTM, color='red', label='Predicted Prices LSTM')
plt.plot(y_test_actual, color='blue', label='Actual Prices')
plt.title('Stock Price Prediction (Last Month)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
#  * PyCaret: Exhibits significant variability but does align well with actual trends.
#  * DeepAR: Heavily under predicts the value and isn't accurate at all.
#  * LSTM: Offers the most reliable predictions, staying closer to the actual prices, though some error persists.

# %% [markdown]
# As we can see the the only model who does not performed well is the DeepAR Model. The other 2 perform much better, while the LSTM is the most accurate of the 3 always the closest to the price. The pycarets does pretty wel too and gets the shifting of the prices much better.
